# %% [markdown]
# ## Data science snippets
# ### Fourier Series and Fourier Transform
#
# > for TeX typesetting plese use [Markdown All in One](https://marketplace.visualstudio.com/items?itemName=yzhang.markdown-all-in-one) extension.

# %%
import numpy as np 
import matplotlib.pyplot as plt 

from scipy.signal import decimate

# %%
N = 1000 # number of spins in the chain
l = 10 # magnetic length
maxf = 2 # frequency normalization 
data = np.loadtxt("dat/math_helix_fm_l10_L1000.dat")
snapshots = data[:N:]

# %%
datafourier = np.fft.fft2(data)
datafourierabs = np.absolute(datafourier)[1:,1: int(np.pi * 10)]

# %%
fig, ax = plt.subplots()

ax.imshow(datafourierabs[::-1], cmap='CMRmap', origin='lower', extent=[0,maxf,0,maxf])
ax.set_xlabel("Wavenumber")
ax.set_ylabel("Frequency")
plt.show()
